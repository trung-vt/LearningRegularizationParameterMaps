# %%
import wandb
from wandb.apis.public.history import HistoryScan

# %%
api = wandb.Api()

# %%
# Get all the logged data points using run.scan_history(). Download all the loss data points logged in history.

team = "wof"
project = "chest_xray"


run_id = "wedf9ud9" # 

run = api.run(f"{team}/{project}/{run_id}")
history = run.scan_history()
# losses = [row["loss"] for row in history]
# print(f"type(losses): {type(losses)}")

# %%
print(f"type(history): {type(history)}")
# Out:
# type(history): <class 'wandb.apis.public.history.HistoryScan'>

# %%
# dir(HistoryScan)

# %%
with open(f"metrics-{run_id}.txt", "w") as f:
    f.write("loss\n")
    # for row in history:
    #     f.write(f"{row}\n")

# %%
with open("a.txt", "w") as f:
    f.write("hello\n")

# %%
print("hello\n")
# Out:
# hello

# %%
for row in history:
    print(f"{row}\n")
# Out:
# {'_step': 0, '_runtime': 139.92195582389832, 'training_loss': 0.0007211714565346484, '_timestamp': 1717756174.2103739}
#
# {'training PSNR': 31.693193435668945, '_step': 1, '_runtime': 139.9221076965332, '_timestamp': 1717756174.2105258}
#
# {'_step': 2, '_runtime': 139.9229655265808, 'training SSIM': 0.8439432733825711, '_timestamp': 1717756174.2113836}
#
# {'_step': 3, '_runtime': 142.23616099357605, 'validation_loss': 0.0006572230122401379, '_timestamp': 1717756176.524579}
#
# {'_step': 4, 'validation PSNR': 32.435890197753906, '_runtime': 142.2363109588623, '_timestamp': 1717756176.524729}
#
# {'_step': 5, 'validation SSIM': 0.8444339535169229, '_runtime': 142.23654913902283, '_timestamp': 1717756176.5249672}
#
# {'_step': 6, '_runtime': 275.6115131378174, 'training_loss': 0.0006908016999659594, '_timestamp': 1717756309.8999312}
#
# {'training PSNR': 31.91526222229004, '_step': 7, '_runtime': 275.6116580963135, '_timestamp': 1717756309.9000762}
#
# ...

# %%
for row in history:
    print(f"{row}\n")
# Out:
# {'_step': 0, '_runtime': 139.92195582389832, 'training_loss': 0.0007211714565346484, '_timestamp': 1717756174.2103739}
#
# {'training PSNR': 31.693193435668945, '_step': 1, '_runtime': 139.9221076965332, '_timestamp': 1717756174.2105258}
#
# {'_step': 2, '_runtime': 139.9229655265808, 'training SSIM': 0.8439432733825711, '_timestamp': 1717756174.2113836}
#
# {'_step': 3, '_runtime': 142.23616099357605, 'validation_loss': 0.0006572230122401379, '_timestamp': 1717756176.524579}
#
# {'_step': 4, 'validation PSNR': 32.435890197753906, '_runtime': 142.2363109588623, '_timestamp': 1717756176.524729}
#
# {'_step': 5, 'validation SSIM': 0.8444339535169229, '_runtime': 142.23654913902283, '_timestamp': 1717756176.5249672}
#
# {'_step': 6, '_runtime': 275.6115131378174, 'training_loss': 0.0006908016999659594, '_timestamp': 1717756309.8999312}
#
# {'training PSNR': 31.91526222229004, '_step': 7, '_runtime': 275.6116580963135, '_timestamp': 1717756309.9000762}
#
# ...
